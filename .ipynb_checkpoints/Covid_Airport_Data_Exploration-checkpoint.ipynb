# %%
#dependencies 
import warnings
warnings.filterwarnings('ignore')

#import all dependencies needed 
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import hvplot.pandas
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt


#ml model packages 
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

#google api imports 
import gmaps 
import requests 
from config import g_key

# %%
#load the data 
file_path = "covid_airport_traffic.csv"
df = pd.read_csv(file_path, index_col=0)
df
# Out:
#                          Date  Version                    AirportName  \
# AggregationMethod
# Daily              2020-07-05      1.0                Kingsford Smith
# Daily              2020-05-28      1.0                Kingsford Smith
# Daily              2020-05-07      1.0                Kingsford Smith
# Daily              2020-06-24      1.0                Kingsford Smith
# Daily              2020-08-05      1.0                Kingsford Smith
# ...                       ...      ...                            ...
# Daily              2020-06-15      1.0  Seattle-Tacoma International
# Daily              2020-10-15      1.0  Seattle-Tacoma International
# Daily              2020-04-01      1.0  Seattle-Tacoma International
# Daily              2020-05-12      1.0  Seattle-Tacoma International
# Daily              2020-10-11      1.0  Seattle-Tacoma International
#
#                    PercentOfBaseline  \
# AggregationMethod
# Daily                             52
# ...

# %%
df = df.dropna()

# %%
df_locations = df["Centroid"].str.split(" ", n=1, expand=True)
df["Longitude"] = df_locations[0]
df["Latitude"] = df_locations[1]
#df.drop(columns=["Centroid"], inplace=True)
df
# Out:
#                          Date  Version                    AirportName  \
# AggregationMethod
# Daily              2020-07-05      1.0                Kingsford Smith
# Daily              2020-05-28      1.0                Kingsford Smith
# Daily              2020-05-07      1.0                Kingsford Smith
# Daily              2020-06-24      1.0                Kingsford Smith
# Daily              2020-08-05      1.0                Kingsford Smith
# ...                       ...      ...                            ...
# Daily              2020-06-15      1.0  Seattle-Tacoma International
# Daily              2020-10-15      1.0  Seattle-Tacoma International
# Daily              2020-04-01      1.0  Seattle-Tacoma International
# Daily              2020-05-12      1.0  Seattle-Tacoma International
# Daily              2020-10-11      1.0  Seattle-Tacoma International
#
#                    PercentOfBaseline  \
# AggregationMethod
# Daily                             52
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Version              float64
# AirportName           object
# PercentOfBaseline      int64
# Centroid              object
# City                  object
# State                 object
# ISO_3166_2            object
# Country               object
# Geography             object
# Longitude             object
# Latitude              object
# dtype: object

# %%
df["Longitude"].str.replace(" ()", "")
# Out:
# AggregationMethod
# Daily     POINT(151.180087713813
# Daily     POINT(151.180087713813
# Daily     POINT(151.180087713813
# Daily     POINT(151.180087713813
# Daily     POINT(151.180087713813
#                   ...
# Daily    POINT(-122.308661576118
# Daily    POINT(-122.308661576118
# Daily    POINT(-122.308661576118
# Daily    POINT(-122.308661576118
# Daily    POINT(-122.308661576118
# Name: Longitude, Length: 5936, dtype: object

# %%
df["Latitude"].str.replace(" ()", "")
# Out:
# AggregationMethod
# Daily    -33.9459774986125)
# Daily    -33.9459774986125)
# Daily    -33.9459774986125)
# Daily    -33.9459774986125)
# Daily    -33.9459774986125)
#                 ...
# Daily     47.4505828917119)
# Daily     47.4505828917119)
# Daily     47.4505828917119)
# Daily     47.4505828917119)
# Daily     47.4505828917119)
# Name: Latitude, Length: 5936, dtype: object

# %%
df["Latitude"] = df.Latitude.astype(float)
#df["Longitude"] = df.Longitude.astype(float)
#df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-81bd018fc584> in <module>
# ----> 1 df["Latitude"] = df.Latitude.astype(float)
#       2 #df["Longitude"] = df.Longitude.astype(float)
#       3 #df
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
gmaps.configure(api_key=g_key)

# %%
# Get the latitude and longitude.
countries = df[["Latitude", "Longitude"]]
weights = df["PercentOfBaseline"]
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(countries, weights=weights))
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\gmaps\geotraitlets.py in _validate_latitude(latitude)
#     298     try:
# --> 299         latitude = float(latitude)
#     300     except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '-33.9459774986125)'
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-30-642b37a13498> in <module>
#       3 weights = df["PercentOfBaseline"]
#       4 fig = gmaps.figure()
# ----> 5 fig.add_layer(gmaps.heatmap_layer(countries, weights=weights))
#       6 fig
#
# ~\anaconda3\envs\mlenv\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
# ...
